# %%
import gym 
from gym import Env
from gym.spaces import Discrete, Box, Dict, Tuple, MultiBinary, MultiDiscrete

import numpy as np
import random
import os

from stable_baselines3 import PPO
from stable_baselines3.common.vec_env import DummyVecEnv
from stable_baselines3.common.evaluation import evaluate_policy

from classes import Deck
from classes import Hand

# %%
class BJEnv(Env):
    def __init__(self):
        self.action_space = Discrete(2) # 0 = Stay, 1 = Draw
        self.observation_space =Box(low=0,high=22, shape=(2,))
        
        self.Deck = Deck()
        self.Hand = Hand(self.Deck)        
        
        self.repeat_num_list = np.array([0])
        self.repeat_mean = 0 #Var to calculate mean val of repeat
        self.state = [self.Deck.draw_a_card(), self.Hand.sum_up()]
        pass
    
    def step(self, action):

        if action == 1:
            self.Hand.draw(self.Deck)
            self.repeat_num_list[-1] += 1

        self.state[1] = self.Hand.sum_up()
        if self.state[1] < 22:
            reward = 1
        else :
            reward = -1
            done = True

        if action == 0:
            while self.state[0] < self.state[1]:
                self.state[0] += self.Deck.draw_a_card()
            done = True
            if self.state[0] > 21 or self.state[1] > self.state[0]:
                reward = 2
            else:
                reward = -1
        else:
            done = False

        info = {}

        return self.state, reward, done, info
    
    def render(self, mode = "human"):
        print('Dealer sum:{}, Player sum:{}'.format(self.Deck.draw_a_card(), self.Hand.sum_up()))
        print("Accual repeat:{}".format(self.repeat_num_list[-1]))
        print("Mean value of all repeats:{}". format(self.repeat_mean))
        print("Best possible val right now:{}".format(1 + ((self.repeat_mean-1)*2)))
        pass
    
    def reset(self):
        self.Deck = Deck()
        self.Hand = Hand(self.Deck)        
        
        self.state = [self.Deck.draw_a_card(), self.Hand.sum_up()]
        self.repeat_num_list = np.append(self.repeat_num_list, 0)
        self.repeat_mean = self.repeat_num_list.mean()
        return self.state

# %%
env = BJEnv()

# %%
print(env.state)
print(env.observation_space.sample())
# Out:
# [10, 17]
# [ 5.644338 15.257443]

# %%
log_path = os.path.join('Trainig', 'Logs')
model = PPO('MlpPolicy', env, verbose=1, tensorboard_log=log_path)
# Out:
# Using cpu device
# Wrapping the env with a `Monitor` wrapper
# Wrapping the env in a DummyVecEnv.

# %%
save_path = os.path.join('Training', 'Saved_models', 'BJ_PPO_200000k')

# %%
model.learn(total_timesteps=200000)
model.save(save_path)
# Out:
# 2022-09-18 23:43:00.715365: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2022-09-18 23:43:00.935116: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libcudart.so.11.0'; dlerror: libcudart.so.11.0: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /home/jakub/.local/lib/python3.10/site-packages/cv2/../../lib64:
# 2022-09-18 23:43:00.935144: I tensorflow/stream_executor/cuda/cudart_stub.cc:29] Ignore above cudart dlerror if you do not have a GPU set up on your machine.
# 2022-09-18 23:43:00.986208: E tensorflow/stream_executor/cuda/cuda_blas.cc:2981] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2022-09-18 23:43:01.825342: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libnvinfer.so.7'; dlerror: libnvinfer.so.7: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /home/jakub/.local/lib/python3.10/site-packages/cv2/../../lib64:
# 2022-09-18 23:43:01.825633: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libnvinfer_plugin.so.7'; dlerror: libnvinfer_plugin.so.7: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /home/jakub/.local/lib/python3.10/site-packages/cv2/../../lib64:
# 2022-09-18 23:43:01.825657: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Cannot dlopen some TensorRT libraries. If you would like to use Nvidia GPU with TensorRT, please make sure the missing libraries mentioned above are installed properly.
# Logging to Trainig/Logs/PPO_26
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 2.17     |
# |    ep_rew_mean     | 0.28     |
# | time/              |          |
# |    fps             | 460      |
# |    iterations      | 1        |
# |    time_elapsed    | 4        |
# |    total_timesteps | 2048     |
# ---------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 2.31        |
# |    ep_rew_mean          | 0.72        |
# | time/                   |             |
# |    fps                  | 606         |
# |    iterations           | 2           |
# |    time_elapsed         | 6           |
# |    total_timesteps      | 4096        |
# | train/                  |             |
# |    approx_kl            | 0.023662236 |
# |    clip_fraction        | 0.404       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.673      |
# |    explained_variance   | -0.0331     |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.72        |
# |    n_updates            | 10          |
# |    policy_gradient_loss | -0.0708     |
# |    value_loss           | 2.19        |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 1.99       |
# |    ep_rew_mean          | 0.97       |
# | time/                   |            |
# |    fps                  | 676        |
# |    iterations           | 3          |
# |    time_elapsed         | 9          |
# |    total_timesteps      | 6144       |
# | train/                  |            |
# |    approx_kl            | 0.05071553 |
# |    clip_fraction        | 0.542      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.586     |
# |    explained_variance   | 0.077      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 0.683      |
# |    n_updates            | 20         |
# |    policy_gradient_loss | -0.0901    |
# |    value_loss           | 1.74       |
# ----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 2.3        |
# |    ep_rew_mean          | 1.26       |
# | time/                   |            |
# |    fps                  | 726        |
# |    iterations           | 4          |
# |    time_elapsed         | 11         |
# |    total_timesteps      | 8192       |
# | train/                  |            |
# |    approx_kl            | 0.06756489 |
# |    clip_fraction        | 0.408      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.45      |
# |    explained_variance   | 0.0561     |
# |    learning_rate        | 0.0003     |
# |    loss                 | 0.724      |
# |    n_updates            | 30         |
# |    policy_gradient_loss | -0.0758    |
# |    value_loss           | 1.61       |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 2.41        |
# |    ep_rew_mean          | 1.57        |
# | time/                   |             |
# |    fps                  | 750         |
# |    iterations           | 5           |
# |    time_elapsed         | 13          |
# |    total_timesteps      | 10240       |
# | train/                  |             |
# |    approx_kl            | 0.042718317 |
# |    clip_fraction        | 0.14        |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.341      |
# |    explained_variance   | 0.0544      |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.591       |
# |    n_updates            | 40          |
# |    policy_gradient_loss | -0.0371     |
# |    value_loss           | 1.35        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 2.38        |
# |    ep_rew_mean          | 1.56        |
# | time/                   |             |
# |    fps                  | 767         |
# |    iterations           | 6           |
# |    time_elapsed         | 16          |
# |    total_timesteps      | 12288       |
# | train/                  |             |
# |    approx_kl            | 0.011826758 |
# |    clip_fraction        | 0.0631      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.26       |
# |    explained_variance   | 0.121       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.719       |
# |    n_updates            | 50          |
# |    policy_gradient_loss | -0.0156     |
# |    value_loss           | 1.12        |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 2.51         |
# |    ep_rew_mean          | 1.9          |
# | time/                   |              |
# |    fps                  | 784          |
# |    iterations           | 7            |
# |    time_elapsed         | 18           |
# |    total_timesteps      | 14336        |
# | train/                  |              |
# |    approx_kl            | 0.0042947703 |
# |    clip_fraction        | 0.0432       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.226       |
# |    explained_variance   | 0.178        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.375        |
# |    n_updates            | 60           |
# |    policy_gradient_loss | -0.00739     |
# |    value_loss           | 0.901        |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 2.4         |
# |    ep_rew_mean          | 1.75        |
# | time/                   |             |
# |    fps                  | 787         |
# |    iterations           | 8           |
# |    time_elapsed         | 20          |
# |    total_timesteps      | 16384       |
# | train/                  |             |
# |    approx_kl            | 0.005833067 |
# |    clip_fraction        | 0.0458      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.197      |
# |    explained_variance   | 0.166       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.512       |
# |    n_updates            | 70          |
# |    policy_gradient_loss | -0.00708    |
# |    value_loss           | 0.973       |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 2.36         |
# |    ep_rew_mean          | 1.82         |
# | time/                   |              |
# |    fps                  | 748          |
# |    iterations           | 9            |
# |    time_elapsed         | 24           |
# |    total_timesteps      | 18432        |
# | train/                  |              |
# |    approx_kl            | 0.0049117217 |
# |    clip_fraction        | 0.0562       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.181       |
# |    explained_variance   | 0.206        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.442        |
# |    n_updates            | 80           |
# |    policy_gradient_loss | -0.0063      |
# |    value_loss           | 0.948        |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 2.51         |
# |    ep_rew_mean          | 1.98         |
# | time/                   |              |
# |    fps                  | 762          |
# |    iterations           | 10           |
# |    time_elapsed         | 26           |
# |    total_timesteps      | 20480        |
# | train/                  |              |
# |    approx_kl            | 0.0024893908 |
# |    clip_fraction        | 0.0364       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.161       |
# |    explained_variance   | 0.179        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.515        |
# |    n_updates            | 90           |
# |    policy_gradient_loss | -0.00529     |
# |    value_loss           | 0.912        |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 2.48        |
# |    ep_rew_mean          | 1.8         |
# | time/                   |             |
# |    fps                  | 773         |
# |    iterations           | 11          |
# |    time_elapsed         | 29          |
# |    total_timesteps      | 22528       |
# | train/                  |             |
# |    approx_kl            | 0.001966456 |
# |    clip_fraction        | 0.0274      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.142      |
# |    explained_variance   | 0.173       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.549       |
# |    n_updates            | 100         |
# |    policy_gradient_loss | -0.00124    |
# |    value_loss           | 0.825       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 2.48        |
# |    ep_rew_mean          | 1.95        |
# | time/                   |             |
# |    fps                  | 780         |
# |    iterations           | 12          |
# |    time_elapsed         | 31          |
# |    total_timesteps      | 24576       |
# | train/                  |             |
# |    approx_kl            | 0.003272299 |
# |    clip_fraction        | 0.0487      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.14       |
# |    explained_variance   | 0.184       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.483       |
# |    n_updates            | 110         |
# |    policy_gradient_loss | -0.00428    |
# |    value_loss           | 1.02        |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 2.31         |
# |    ep_rew_mean          | 1.59         |
# | time/                   |              |
# |    fps                  | 757          |
# |    iterations           | 13           |
# |    time_elapsed         | 35           |
# |    total_timesteps      | 26624        |
# | train/                  |              |
# |    approx_kl            | 0.0043637827 |
# |    clip_fraction        | 0.0451       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.142       |
# |    explained_variance   | 0.196        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.352        |
# |    n_updates            | 120          |
# |    policy_gradient_loss | 9.98e-06     |
# |    value_loss           | 0.843        |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 2.49         |
# |    ep_rew_mean          | 1.79         |
# | time/                   |              |
# |    fps                  | 762          |
# |    iterations           | 14           |
# |    time_elapsed         | 37           |
# |    total_timesteps      | 28672        |
# | train/                  |              |
# |    approx_kl            | 0.0023903276 |
# |    clip_fraction        | 0.042        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.133       |
# |    explained_variance   | 0.206        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.41         |
# |    n_updates            | 130          |
# |    policy_gradient_loss | -0.000606    |
# |    value_loss           | 0.812        |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 2.5          |
# |    ep_rew_mean          | 1.86         |
# | time/                   |              |
# |    fps                  | 765          |
# |    iterations           | 15           |
# |    time_elapsed         | 40           |
# |    total_timesteps      | 30720        |
# | train/                  |              |
# |    approx_kl            | 0.0035405979 |
# |    clip_fraction        | 0.0308       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.122       |
# |    explained_variance   | 0.207        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.374        |
# |    n_updates            | 140          |
# |    policy_gradient_loss | -0.000205    |
# |    value_loss           | 0.746        |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 2.7         |
# |    ep_rew_mean          | 2.05        |
# | time/                   |             |
# |    fps                  | 772         |
# |    iterations           | 16          |
# |    time_elapsed         | 42          |
# |    total_timesteps      | 32768       |
# | train/                  |             |
# |    approx_kl            | 0.007693644 |
# |    clip_fraction        | 0.0389      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.117      |
# |    explained_variance   | 0.218       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.375       |
# |    n_updates            | 150         |
# |    policy_gradient_loss | 0.00255     |
# |    value_loss           | 0.714       |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 2.51         |
# |    ep_rew_mean          | 1.86         |
# | time/                   |              |
# |    fps                  | 756          |
# |    iterations           | 17           |
# |    time_elapsed         | 46           |
# |    total_timesteps      | 34816        |
# | train/                  |              |
# |    approx_kl            | 0.0038436388 |
# |    clip_fraction        | 0.0423       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.107       |
# |    explained_variance   | 0.253        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.45         |
# |    n_updates            | 160          |
# |    policy_gradient_loss | 0.00522      |
# |    value_loss           | 0.647        |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 2.56         |
# |    ep_rew_mean          | 1.98         |
# | time/                   |              |
# |    fps                  | 757          |
# |    iterations           | 18           |
# |    time_elapsed         | 48           |
# |    total_timesteps      | 36864        |
# | train/                  |              |
# |    approx_kl            | 0.0011406944 |
# |    clip_fraction        | 0.0373       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.109       |
# |    explained_variance   | 0.261        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.142        |
# |    n_updates            | 170          |
# |    policy_gradient_loss | 0.0041       |
# |    value_loss           | 0.639        |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 2.73         |
# |    ep_rew_mean          | 2.01         |
# | time/                   |              |
# |    fps                  | 744          |
# |    iterations           | 19           |
# |    time_elapsed         | 52           |
# |    total_timesteps      | 38912        |
# | train/                  |              |
# |    approx_kl            | 0.0058484827 |
# |    clip_fraction        | 0.0431       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.1         |
# |    explained_variance   | 0.278        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.178        |
# |    n_updates            | 180          |
# |    policy_gradient_loss | 0.00619      |
# |    value_loss           | 0.598        |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 2.67         |
# |    ep_rew_mean          | 2.01         |
# | time/                   |              |
# |    fps                  | 749          |
# |    iterations           | 20           |
# |    time_elapsed         | 54           |
# |    total_timesteps      | 40960        |
# | train/                  |              |
# |    approx_kl            | 0.0056617623 |
# |    clip_fraction        | 0.0442       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.102       |
# |    explained_variance   | 0.198        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.443        |
# |    n_updates            | 190          |
# |    policy_gradient_loss | 0.00455      |
# |    value_loss           | 0.757        |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 2.73         |
# |    ep_rew_mean          | 2.09         |
# | time/                   |              |
# |    fps                  | 740          |
# |    iterations           | 21           |
# |    time_elapsed         | 58           |
# |    total_timesteps      | 43008        |
# | train/                  |              |
# |    approx_kl            | 0.0059916805 |
# |    clip_fraction        | 0.0382       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.0937      |
# |    explained_variance   | 0.252        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.261        |
# |    n_updates            | 200          |
# |    policy_gradient_loss | 0.00471      |
# |    value_loss           | 0.552        |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 2.8          |
# |    ep_rew_mean          | 2.09         |
# | time/                   |              |
# |    fps                  | 744          |
# |    iterations           | 22           |
# |    time_elapsed         | 60           |
# |    total_timesteps      | 45056        |
# | train/                  |              |
# |    approx_kl            | 0.0034268482 |
# |    clip_fraction        | 0.0381       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.0874      |
# |    explained_variance   | 0.218        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.223        |
# |    n_updates            | 210          |
# |    policy_gradient_loss | 0.00552      |
# |    value_loss           | 0.605        |
# ------------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 2.61       |
# |    ep_rew_mean          | 1.94       |
# | time/                   |            |
# |    fps                  | 747        |
# |    iterations           | 23         |
# |    time_elapsed         | 63         |
# |    total_timesteps      | 47104      |
# | train/                  |            |
# |    approx_kl            | 0.00548724 |
# |    clip_fraction        | 0.0533     |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.0876    |
# |    explained_variance   | 0.291      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 0.273      |
# |    n_updates            | 220        |
# |    policy_gradient_loss | 0.00837    |
# |    value_loss           | 0.502      |
# ----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 2.78         |
# |    ep_rew_mean          | 2.13         |
# | time/                   |              |
# |    fps                  | 734          |
# |    iterations           | 24           |
# |    time_elapsed         | 66           |
# |    total_timesteps      | 49152        |
# | train/                  |              |
# |    approx_kl            | 0.0077664177 |
# |    clip_fraction        | 0.0434       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.0841      |
# |    explained_variance   | 0.239        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.227        |
# |    n_updates            | 230          |
# |    policy_gradient_loss | 0.00847      |
# |    value_loss           | 0.579        |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 2.64        |
# |    ep_rew_mean          | 1.84        |
# | time/                   |             |
# |    fps                  | 738         |
# |    iterations           | 25          |
# |    time_elapsed         | 69          |
# |    total_timesteps      | 51200       |
# | train/                  |             |
# |    approx_kl            | 0.006639517 |
# |    clip_fraction        | 0.0497      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.0882     |
# |    explained_variance   | 0.241       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.39        |
# |    n_updates            | 240         |
# |    policy_gradient_loss | 0.00615     |
# |    value_loss           | 0.591       |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 2.41         |
# |    ep_rew_mean          | 1.85         |
# | time/                   |              |
# |    fps                  | 742          |
# |    iterations           | 26           |
# |    time_elapsed         | 71           |
# |    total_timesteps      | 53248        |
# | train/                  |              |
# |    approx_kl            | 0.0024718912 |
# |    clip_fraction        | 0.0359       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.0811      |
# |    explained_variance   | 0.224        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.447        |
# |    n_updates            | 250          |
# |    policy_gradient_loss | 0.00384      |
# |    value_loss           | 0.665        |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 2.69        |
# |    ep_rew_mean          | 2.04        |
# | time/                   |             |
# |    fps                  | 733         |
# |    iterations           | 27          |
# |    time_elapsed         | 75          |
# |    total_timesteps      | 55296       |
# | train/                  |             |
# |    approx_kl            | 0.009444922 |
# |    clip_fraction        | 0.0411      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.0885     |
# |    explained_variance   | 0.23        |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.36        |
# |    n_updates            | 260         |
# |    policy_gradient_loss | 0.0075      |
# |    value_loss           | 0.739       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 2.69        |
# |    ep_rew_mean          | 2           |
# | time/                   |             |
# |    fps                  | 736         |
# |    iterations           | 28          |
# |    time_elapsed         | 77          |
# |    total_timesteps      | 57344       |
# | train/                  |             |
# |    approx_kl            | 0.018512044 |
# |    clip_fraction        | 0.0467      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.0858     |
# |    explained_variance   | 0.244       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.301       |
# |    n_updates            | 270         |
# |    policy_gradient_loss | 0.00716     |
# |    value_loss           | 0.692       |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 2.77         |
# |    ep_rew_mean          | 2.07         |
# | time/                   |              |
# |    fps                  | 739          |
# |    iterations           | 29           |
# |    time_elapsed         | 80           |
# |    total_timesteps      | 59392        |
# | train/                  |              |
# |    approx_kl            | 0.0044134897 |
# |    clip_fraction        | 0.0544       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.0857      |
# |    explained_variance   | 0.261        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.406        |
# |    n_updates            | 280          |
# |    policy_gradient_loss | 0.00548      |
# |    value_loss           | 0.599        |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 2.47         |
# |    ep_rew_mean          | 1.93         |
# | time/                   |              |
# |    fps                  | 733          |
# |    iterations           | 30           |
# |    time_elapsed         | 83           |
# |    total_timesteps      | 61440        |
# | train/                  |              |
# |    approx_kl            | 0.0036758357 |
# |    clip_fraction        | 0.0403       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.0868      |
# |    explained_variance   | 0.247        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.334        |
# |    n_updates            | 290          |
# |    policy_gradient_loss | 0.00278      |
# |    value_loss           | 0.702        |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 2.6          |
# |    ep_rew_mean          | 1.99         |
# | time/                   |              |
# |    fps                  | 736          |
# |    iterations           | 31           |
# |    time_elapsed         | 86           |
# |    total_timesteps      | 63488        |
# | train/                  |              |
# |    approx_kl            | 0.0024955408 |
# |    clip_fraction        | 0.0333       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.0851      |
# |    explained_variance   | 0.227        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.348        |
# |    n_updates            | 300          |
# |    policy_gradient_loss | 0.00175      |
# |    value_loss           | 0.688        |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 2.65        |
# |    ep_rew_mean          | 1.88        |
# | time/                   |             |
# |    fps                  | 740         |
# |    iterations           | 32          |
# |    time_elapsed         | 88          |
# |    total_timesteps      | 65536       |
# | train/                  |             |
# |    approx_kl            | 0.004013063 |
# |    clip_fraction        | 0.0404      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.0815     |
# |    explained_variance   | 0.221       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.528       |
# |    n_updates            | 310         |
# |    policy_gradient_loss | 0.00472     |
# |    value_loss           | 0.771       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 2.49        |
# |    ep_rew_mean          | 1.82        |
# | time/                   |             |
# |    fps                  | 744         |
# |    iterations           | 33          |
# |    time_elapsed         | 90          |
# |    total_timesteps      | 67584       |
# | train/                  |             |
# |    approx_kl            | 0.007503333 |
# |    clip_fraction        | 0.0409      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.0809     |
# |    explained_variance   | 0.257       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.232       |
# |    n_updates            | 320         |
# |    policy_gradient_loss | 0.00983     |
# |    value_loss           | 0.653       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 2.7         |
# |    ep_rew_mean          | 1.94        |
# | time/                   |             |
# |    fps                  | 747         |
# |    iterations           | 34          |
# |    time_elapsed         | 93          |
# |    total_timesteps      | 69632       |
# | train/                  |             |
# |    approx_kl            | 0.004418787 |
# |    clip_fraction        | 0.0335      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.0888     |
# |    explained_variance   | 0.241       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.162       |
# |    n_updates            | 330         |
# |    policy_gradient_loss | 0.00281     |
# |    value_loss           | 0.73        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 2.45        |
# |    ep_rew_mean          | 2.01        |
# | time/                   |             |
# |    fps                  | 751         |
# |    iterations           | 35          |
# |    time_elapsed         | 95          |
# |    total_timesteps      | 71680       |
# | train/                  |             |
# |    approx_kl            | 0.013602486 |
# |    clip_fraction        | 0.0475      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.0778     |
# |    explained_variance   | 0.259       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.236       |
# |    n_updates            | 340         |
# |    policy_gradient_loss | 0.00603     |
# |    value_loss           | 0.553       |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 2.6          |
# |    ep_rew_mean          | 2.1          |
# | time/                   |              |
# |    fps                  | 754          |
# |    iterations           | 36           |
# |    time_elapsed         | 97           |
# |    total_timesteps      | 73728        |
# | train/                  |              |
# |    approx_kl            | 0.0034825762 |
# |    clip_fraction        | 0.0406       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.0809      |
# |    explained_variance   | 0.207        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.326        |
# |    n_updates            | 350          |
# |    policy_gradient_loss | 0.00537      |
# |    value_loss           | 0.724        |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 2.59        |
# |    ep_rew_mean          | 2.03        |
# | time/                   |             |
# |    fps                  | 757         |
# |    iterations           | 37          |
# |    time_elapsed         | 100         |
# |    total_timesteps      | 75776       |
# | train/                  |             |
# |    approx_kl            | 0.008432872 |
# |    clip_fraction        | 0.0458      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.0853     |
# |    explained_variance   | 0.221       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.194       |
# |    n_updates            | 360         |
# |    policy_gradient_loss | 0.00542     |
# |    value_loss           | 0.72        |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 2.52         |
# |    ep_rew_mean          | 1.81         |
# | time/                   |              |
# |    fps                  | 748          |
# |    iterations           | 38           |
# |    time_elapsed         | 103          |
# |    total_timesteps      | 77824        |
# | train/                  |              |
# |    approx_kl            | 0.0100346925 |
# |    clip_fraction        | 0.0374       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.0826      |
# |    explained_variance   | 0.252        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.464        |
# |    n_updates            | 370          |
# |    policy_gradient_loss | 0.00248      |
# |    value_loss           | 0.815        |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 2.45         |
# |    ep_rew_mean          | 1.88         |
# | time/                   |              |
# |    fps                  | 738          |
# |    iterations           | 39           |
# |    time_elapsed         | 108          |
# |    total_timesteps      | 79872        |
# | train/                  |              |
# |    approx_kl            | 0.0017258888 |
# |    clip_fraction        | 0.0365       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.0848      |
# |    explained_variance   | 0.203        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.357        |
# |    n_updates            | 380          |
# |    policy_gradient_loss | 0.00165      |
# |    value_loss           | 0.817        |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 2.53        |
# |    ep_rew_mean          | 1.81        |
# | time/                   |             |
# |    fps                  | 739         |
# |    iterations           | 40          |
# |    time_elapsed         | 110         |
# |    total_timesteps      | 81920       |
# | train/                  |             |
# |    approx_kl            | 0.026102245 |
# |    clip_fraction        | 0.0493      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.0839     |
# |    explained_variance   | 0.209       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.376       |
# |    n_updates            | 390         |
# |    policy_gradient_loss | 0.00298     |
# |    value_loss           | 0.737       |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 2.47         |
# |    ep_rew_mean          | 1.84         |
# | time/                   |              |
# |    fps                  | 732          |
# |    iterations           | 41           |
# |    time_elapsed         | 114          |
# |    total_timesteps      | 83968        |
# | train/                  |              |
# |    approx_kl            | 0.0014572766 |
# |    clip_fraction        | 0.0338       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.0782      |
# |    explained_variance   | 0.226        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.203        |
# |    n_updates            | 400          |
# |    policy_gradient_loss | 0.00493      |
# |    value_loss           | 0.709        |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 2.73         |
# |    ep_rew_mean          | 2.19         |
# | time/                   |              |
# |    fps                  | 726          |
# |    iterations           | 42           |
# |    time_elapsed         | 118          |
# |    total_timesteps      | 86016        |
# | train/                  |              |
# |    approx_kl            | 0.0028604793 |
# |    clip_fraction        | 0.0388       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.0834      |
# |    explained_variance   | 0.228        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.423        |
# |    n_updates            | 410          |
# |    policy_gradient_loss | 0.000623     |
# |    value_loss           | 0.803        |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 2.4          |
# |    ep_rew_mean          | 2.07         |
# | time/                   |              |
# |    fps                  | 728          |
# |    iterations           | 43           |
# |    time_elapsed         | 120          |
# |    total_timesteps      | 88064        |
# | train/                  |              |
# |    approx_kl            | 0.0066195843 |
# |    clip_fraction        | 0.0382       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.0849      |
# |    explained_variance   | 0.23         |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.323        |
# |    n_updates            | 420          |
# |    policy_gradient_loss | 0.00586      |
# |    value_loss           | 0.662        |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 2.5          |
# |    ep_rew_mean          | 1.85         |
# | time/                   |              |
# |    fps                  | 728          |
# |    iterations           | 44           |
# |    time_elapsed         | 123          |
# |    total_timesteps      | 90112        |
# | train/                  |              |
# |    approx_kl            | 0.0071559474 |
# |    clip_fraction        | 0.0328       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.0827      |
# |    explained_variance   | 0.193        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.401        |
# |    n_updates            | 430          |
# |    policy_gradient_loss | 0.00284      |
# |    value_loss           | 0.792        |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 2.6          |
# |    ep_rew_mean          | 1.93         |
# | time/                   |              |
# |    fps                  | 720          |
# |    iterations           | 45           |
# |    time_elapsed         | 127          |
# |    total_timesteps      | 92160        |
# | train/                  |              |
# |    approx_kl            | 0.0070021315 |
# |    clip_fraction        | 0.0474       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.0789      |
# |    explained_variance   | 0.297        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.276        |
# |    n_updates            | 440          |
# |    policy_gradient_loss | 0.00824      |
# |    value_loss           | 0.587        |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 2.76         |
# |    ep_rew_mean          | 2.18         |
# | time/                   |              |
# |    fps                  | 716          |
# |    iterations           | 46           |
# |    time_elapsed         | 131          |
# |    total_timesteps      | 94208        |
# | train/                  |              |
# |    approx_kl            | 0.0049717636 |
# |    clip_fraction        | 0.0403       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.0826      |
# |    explained_variance   | 0.257        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.288        |
# |    n_updates            | 450          |
# |    policy_gradient_loss | 0.00521      |
# |    value_loss           | 0.56         |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 2.58        |
# |    ep_rew_mean          | 1.95        |
# | time/                   |             |
# |    fps                  | 718         |
# |    iterations           | 47          |
# |    time_elapsed         | 133         |
# |    total_timesteps      | 96256       |
# | train/                  |             |
# |    approx_kl            | 0.024182394 |
# |    clip_fraction        | 0.0524      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.0798     |
# |    explained_variance   | 0.253       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.411       |
# |    n_updates            | 460         |
# |    policy_gradient_loss | 0.00846     |
# |    value_loss           | 0.616       |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 2.63         |
# |    ep_rew_mean          | 2.06         |
# | time/                   |              |
# |    fps                  | 714          |
# |    iterations           | 48           |
# |    time_elapsed         | 137          |
# |    total_timesteps      | 98304        |
# | train/                  |              |
# |    approx_kl            | 0.0032299224 |
# |    clip_fraction        | 0.0394       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.0802      |
# |    explained_variance   | 0.291        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.304        |
# |    n_updates            | 470          |
# |    policy_gradient_loss | 0.00495      |
# |    value_loss           | 0.542        |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 2.65        |
# |    ep_rew_mean          | 2.14        |
# | time/                   |             |
# |    fps                  | 711         |
# |    iterations           | 49          |
# |    time_elapsed         | 141         |
# |    total_timesteps      | 100352      |
# | train/                  |             |
# |    approx_kl            | 0.004426537 |
# |    clip_fraction        | 0.0396      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.0864     |
# |    explained_variance   | 0.249       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.458       |
# |    n_updates            | 480         |
# |    policy_gradient_loss | 0.0041      |
# |    value_loss           | 0.73        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 2.65        |
# |    ep_rew_mean          | 1.95        |
# | time/                   |             |
# |    fps                  | 707         |
# |    iterations           | 50          |
# |    time_elapsed         | 144         |
# |    total_timesteps      | 102400      |
# | train/                  |             |
# |    approx_kl            | 0.005367064 |
# |    clip_fraction        | 0.0439      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.0882     |
# |    explained_variance   | 0.254       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.356       |
# |    n_updates            | 490         |
# |    policy_gradient_loss | 0.00713     |
# |    value_loss           | 0.707       |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 2.67         |
# |    ep_rew_mean          | 1.95         |
# | time/                   |              |
# |    fps                  | 704          |
# |    iterations           | 51           |
# |    time_elapsed         | 148          |
# |    total_timesteps      | 104448       |
# | train/                  |              |
# |    approx_kl            | 0.0070346463 |
# |    clip_fraction        | 0.0397       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.075       |
# |    explained_variance   | 0.281        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.306        |
# |    n_updates            | 500          |
# |    policy_gradient_loss | 0.00725      |
# |    value_loss           | 0.654        |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 2.69         |
# |    ep_rew_mean          | 1.95         |
# | time/                   |              |
# |    fps                  | 707          |
# |    iterations           | 52           |
# |    time_elapsed         | 150          |
# |    total_timesteps      | 106496       |
# | train/                  |              |
# |    approx_kl            | 0.0029465472 |
# |    clip_fraction        | 0.043        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.0801      |
# |    explained_variance   | 0.235        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.35         |
# |    n_updates            | 510          |
# |    policy_gradient_loss | 0.00646      |
# |    value_loss           | 0.68         |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 2.63        |
# |    ep_rew_mean          | 1.97        |
# ...
# | time/                   |              |
# |    fps                  | 697          |
# |    iterations           | 81           |
# |    time_elapsed         | 237          |
# |    total_timesteps      | 165888       |
# | train/                  |              |
# |    approx_kl            | 0.0017975491 |
# |    clip_fraction        | 0.0389       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.0833      |
# |    explained_variance   | 0.233        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.415        |
# |    n_updates            | 800          |
# |    policy_gradient_loss | 0.00505      |
# |    value_loss           | 0.714        |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 2.63        |
# |    ep_rew_mean          | 1.98        |
# | time/                   |             |
# |    fps                  | 695         |
# |    iterations           | 82          |
# |    time_elapsed         | 241         |
# |    total_timesteps      | 167936      |
# | train/                  |             |
# |    approx_kl            | 0.008124842 |
# |    clip_fraction        | 0.0307      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.0879     |
# |    explained_variance   | 0.227       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.351       |
# |    n_updates            | 810         |
# |    policy_gradient_loss | 0.00294     |
# |    value_loss           | 0.696       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 2.42        |
# |    ep_rew_mean          | 1.82        |
# | time/                   |             |
# |    fps                  | 696         |
# |    iterations           | 83          |
# |    time_elapsed         | 243         |
# |    total_timesteps      | 169984      |
# | train/                  |             |
# |    approx_kl            | 0.001482206 |
# |    clip_fraction        | 0.0374      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.0861     |
# |    explained_variance   | 0.232       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.302       |
# |    n_updates            | 820         |
# |    policy_gradient_loss | 0.004       |
# |    value_loss           | 0.699       |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 2.62         |
# |    ep_rew_mean          | 1.98         |
# | time/                   |              |
# |    fps                  | 694          |
# |    iterations           | 84           |
# |    time_elapsed         | 247          |
# |    total_timesteps      | 172032       |
# | train/                  |              |
# |    approx_kl            | 0.0045785597 |
# |    clip_fraction        | 0.0391       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.0815      |
# |    explained_variance   | 0.251        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.375        |
# |    n_updates            | 830          |
# |    policy_gradient_loss | 0.00439      |
# |    value_loss           | 0.642        |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 2.42         |
# |    ep_rew_mean          | 1.85         |
# | time/                   |              |
# |    fps                  | 696          |
# |    iterations           | 85           |
# |    time_elapsed         | 250          |
# |    total_timesteps      | 174080       |
# | train/                  |              |
# |    approx_kl            | 0.0028749453 |
# |    clip_fraction        | 0.0314       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.0824      |
# |    explained_variance   | 0.267        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.344        |
# |    n_updates            | 840          |
# |    policy_gradient_loss | 0.00219      |
# |    value_loss           | 0.693        |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 2.51         |
# |    ep_rew_mean          | 1.81         |
# | time/                   |              |
# |    fps                  | 694          |
# |    iterations           | 86           |
# |    time_elapsed         | 253          |
# |    total_timesteps      | 176128       |
# | train/                  |              |
# |    approx_kl            | 0.0034476714 |
# |    clip_fraction        | 0.0347       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.0767      |
# |    explained_variance   | 0.251        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.237        |
# |    n_updates            | 850          |
# |    policy_gradient_loss | 0.00435      |
# |    value_loss           | 0.587        |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 2.56        |
# |    ep_rew_mean          | 1.96        |
# | time/                   |             |
# |    fps                  | 695         |
# |    iterations           | 87          |
# |    time_elapsed         | 256         |
# |    total_timesteps      | 178176      |
# | train/                  |             |
# |    approx_kl            | 0.004936099 |
# |    clip_fraction        | 0.0411      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.0812     |
# |    explained_variance   | 0.211       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.286       |
# |    n_updates            | 860         |
# |    policy_gradient_loss | 0.00433     |
# |    value_loss           | 0.66        |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 2.6          |
# |    ep_rew_mean          | 1.93         |
# | time/                   |              |
# |    fps                  | 693          |
# |    iterations           | 88           |
# |    time_elapsed         | 259          |
# |    total_timesteps      | 180224       |
# | train/                  |              |
# |    approx_kl            | 0.0025880025 |
# |    clip_fraction        | 0.0361       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.0825      |
# |    explained_variance   | 0.226        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.35         |
# |    n_updates            | 870          |
# |    policy_gradient_loss | 0.00336      |
# |    value_loss           | 0.805        |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 2.53         |
# |    ep_rew_mean          | 1.93         |
# | time/                   |              |
# |    fps                  | 695          |
# |    iterations           | 89           |
# |    time_elapsed         | 262          |
# |    total_timesteps      | 182272       |
# | train/                  |              |
# |    approx_kl            | 0.0056846673 |
# |    clip_fraction        | 0.0349       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.0794      |
# |    explained_variance   | 0.242        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.21         |
# |    n_updates            | 880          |
# |    policy_gradient_loss | -0.00127     |
# |    value_loss           | 0.709        |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 2.53         |
# |    ep_rew_mean          | 1.95         |
# | time/                   |              |
# |    fps                  | 693          |
# |    iterations           | 90           |
# |    time_elapsed         | 265          |
# |    total_timesteps      | 184320       |
# | train/                  |              |
# |    approx_kl            | 0.0036256227 |
# |    clip_fraction        | 0.0285       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.0779      |
# |    explained_variance   | 0.23         |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.373        |
# |    n_updates            | 890          |
# |    policy_gradient_loss | 0.00203      |
# |    value_loss           | 0.773        |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 2.44         |
# |    ep_rew_mean          | 1.79         |
# | time/                   |              |
# |    fps                  | 694          |
# |    iterations           | 91           |
# |    time_elapsed         | 268          |
# |    total_timesteps      | 186368       |
# | train/                  |              |
# |    approx_kl            | 0.0038622967 |
# |    clip_fraction        | 0.038        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.0801      |
# |    explained_variance   | 0.236        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.386        |
# |    n_updates            | 900          |
# |    policy_gradient_loss | 0.0019       |
# |    value_loss           | 0.801        |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 2.46         |
# |    ep_rew_mean          | 1.89         |
# | time/                   |              |
# |    fps                  | 692          |
# |    iterations           | 92           |
# |    time_elapsed         | 272          |
# |    total_timesteps      | 188416       |
# | train/                  |              |
# |    approx_kl            | 0.0035703063 |
# |    clip_fraction        | 0.038        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.0795      |
# |    explained_variance   | 0.239        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.379        |
# |    n_updates            | 910          |
# |    policy_gradient_loss | 0.00377      |
# |    value_loss           | 0.778        |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 2.73         |
# |    ep_rew_mean          | 2.05         |
# | time/                   |              |
# |    fps                  | 693          |
# |    iterations           | 93           |
# |    time_elapsed         | 274          |
# |    total_timesteps      | 190464       |
# | train/                  |              |
# |    approx_kl            | 0.0059483848 |
# |    clip_fraction        | 0.0378       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.0835      |
# |    explained_variance   | 0.244        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.399        |
# |    n_updates            | 920          |
# |    policy_gradient_loss | 0.00159      |
# |    value_loss           | 0.734        |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 2.85         |
# |    ep_rew_mean          | 2.21         |
# | time/                   |              |
# |    fps                  | 694          |
# |    iterations           | 94           |
# |    time_elapsed         | 277          |
# |    total_timesteps      | 192512       |
# | train/                  |              |
# |    approx_kl            | 0.0071799904 |
# |    clip_fraction        | 0.0437       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.0859      |
# |    explained_variance   | 0.284        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.348        |
# |    n_updates            | 930          |
# |    policy_gradient_loss | 0.00255      |
# |    value_loss           | 0.562        |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 2.74         |
# |    ep_rew_mean          | 2.09         |
# | time/                   |              |
# |    fps                  | 695          |
# |    iterations           | 95           |
# |    time_elapsed         | 279          |
# |    total_timesteps      | 194560       |
# | train/                  |              |
# |    approx_kl            | 0.0041947034 |
# |    clip_fraction        | 0.048        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.0861      |
# |    explained_variance   | 0.271        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.407        |
# |    n_updates            | 940          |
# |    policy_gradient_loss | 0.00812      |
# |    value_loss           | 0.608        |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 2.67        |
# |    ep_rew_mean          | 2.01        |
# | time/                   |             |
# |    fps                  | 696         |
# |    iterations           | 96          |
# |    time_elapsed         | 282         |
# |    total_timesteps      | 196608      |
# | train/                  |             |
# |    approx_kl            | 0.021203337 |
# |    clip_fraction        | 0.0547      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.0788     |
# |    explained_variance   | 0.288       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.239       |
# |    n_updates            | 950         |
# |    policy_gradient_loss | 0.0022      |
# |    value_loss           | 0.557       |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 2.62         |
# |    ep_rew_mean          | 2.05         |
# | time/                   |              |
# |    fps                  | 694          |
# |    iterations           | 97           |
# |    time_elapsed         | 285          |
# |    total_timesteps      | 198656       |
# | train/                  |              |
# |    approx_kl            | 0.0022688555 |
# |    clip_fraction        | 0.0396       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.0896      |
# |    explained_variance   | 0.242        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.218        |
# |    n_updates            | 960          |
# |    policy_gradient_loss | 0.00606      |
# |    value_loss           | 0.665        |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 2.74        |
# |    ep_rew_mean          | 2.11        |
# | time/                   |             |
# |    fps                  | 695         |
# |    iterations           | 98          |
# |    time_elapsed         | 288         |
# |    total_timesteps      | 200704      |
# | train/                  |             |
# |    approx_kl            | 0.008588998 |
# |    clip_fraction        | 0.0407      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.0856     |
# |    explained_variance   | 0.293       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.271       |
# |    n_updates            | 970         |
# |    policy_gradient_loss | 0.00708     |
# |    value_loss           | 0.548       |
# -----------------------------------------

# %%
model = PPO.load(save_path)
evaluate_policy(model, env, n_eval_episodes=50, render=True)
# Out:
# Dealer sum:8, Player sum:14
# Accual repeat:1
# Mean value of all repeats:1.5294836272040302
# Best possible val right now:2.0589672544080604
# Dealer sum:6, Player sum:16
# Accual repeat:2
# Mean value of all repeats:1.5294836272040302
# Best possible val right now:2.0589672544080604
# Dealer sum:7, Player sum:25
# Accual repeat:3
# Mean value of all repeats:1.5294836272040302
# Best possible val right now:2.0589672544080604
# Dealer sum:2, Player sum:16
# Accual repeat:0
# Mean value of all repeats:1.5295021473281194
# Best possible val right now:2.059004294656239
# Dealer sum:4, Player sum:20
# Accual repeat:1
# Mean value of all repeats:1.5295021473281194
# Best possible val right now:2.059004294656239
# Dealer sum:1, Player sum:26
# Accual repeat:2
# Mean value of all repeats:1.5295021473281194
# Best possible val right now:2.059004294656239
# Dealer sum:8, Player sum:11
# Accual repeat:0
# Mean value of all repeats:1.5295080728445127
# Best possible val right now:2.0590161456890255
# Dealer sum:4, Player sum:17
# Accual repeat:1
# Mean value of all repeats:1.5295080728445127
# Best possible val right now:2.0590161456890255
# Dealer sum:3, Player sum:26
# Accual repeat:2
# Mean value of all repeats:1.5295080728445127
# Best possible val right now:2.0590161456890255
# Dealer sum:7, Player sum:14
# Accual repeat:0
# Mean value of all repeats:1.5295139982116546
# Best possible val right now:2.059027996423309
# Dealer sum:10, Player sum:22
# Accual repeat:1
# Mean value of all repeats:1.5295139982116546
# Best possible val right now:2.059027996423309
# Dealer sum:1, Player sum:6
# Accual repeat:0
# Mean value of all repeats:1.5295073296055615
# Best possible val right now:2.059014659211123
# Dealer sum:10, Player sum:16
# Accual repeat:1
# Mean value of all repeats:1.5295073296055615
# Best possible val right now:2.059014659211123
# Dealer sum:11, Player sum:22
# Accual repeat:2
# Mean value of all repeats:1.5295073296055615
# Best possible val right now:2.059014659211123
# Dealer sum:7, Player sum:10
# Accual repeat:0
# Mean value of all repeats:1.5295132548328192
# Best possible val right now:2.0590265096656384
# Dealer sum:5, Player sum:11
# Accual repeat:1
# Mean value of all repeats:1.5295132548328192
# Best possible val right now:2.0590265096656384
# Dealer sum:11, Player sum:21
# Accual repeat:2
# Mean value of all repeats:1.5295132548328192
# Best possible val right now:2.0590265096656384
# Dealer sum:2, Player sum:16
# Accual repeat:0
# Mean value of all repeats:1.529519179910838
# Best possible val right now:2.059038359821676
# Dealer sum:10, Player sum:19
# Accual repeat:1
# Mean value of all repeats:1.529519179910838
# Best possible val right now:2.059038359821676
# Dealer sum:4, Player sum:29
# Accual repeat:2
# Mean value of all repeats:1.529519179910838
# Best possible val right now:2.059038359821676
# Dealer sum:7, Player sum:11
# Accual repeat:0
# Mean value of all repeats:1.5295251048396237
# Best possible val right now:2.0590502096792473
# Dealer sum:1, Player sum:21
# Accual repeat:1
# Mean value of all repeats:1.5295251048396237
# Best possible val right now:2.0590502096792473
# Dealer sum:1, Player sum:12
# Accual repeat:0
# Mean value of all repeats:1.5295184364295789
# Best possible val right now:2.0590368728591577
# Dealer sum:1, Player sum:17
# Accual repeat:1
# Mean value of all repeats:1.5295184364295789
# Best possible val right now:2.0590368728591577
# Dealer sum:1, Player sum:27
# Accual repeat:2
# Mean value of all repeats:1.5295184364295789
# Best possible val right now:2.0590368728591577
# Dealer sum:9, Player sum:11
# Accual repeat:0
# Mean value of all repeats:1.5295243612185017
# Best possible val right now:2.0590487224370033
# Dealer sum:8, Player sum:13
# Accual repeat:1
# Mean value of all repeats:1.5295243612185017
# Best possible val right now:2.0590487224370033
# Dealer sum:11, Player sum:19
# Accual repeat:2
# Mean value of all repeats:1.5295243612185017
# Best possible val right now:2.0590487224370033
# Dealer sum:5, Player sum:21
# Accual repeat:3
# Mean value of all repeats:1.5295243612185017
# Best possible val right now:2.0590487224370033
# Dealer sum:10, Player sum:12
# Accual repeat:0
# Mean value of all repeats:1.5295428787306384
# Best possible val right now:2.059085757461277
# Dealer sum:4, Player sum:18
# Accual repeat:1
# Mean value of all repeats:1.5295428787306384
# Best possible val right now:2.059085757461277
# Dealer sum:6, Player sum:28
# Accual repeat:2
# Mean value of all repeats:1.5295428787306384
# Best possible val right now:2.059085757461277
# Dealer sum:10, Player sum:15
# Accual repeat:0
# Mean value of all repeats:1.529548803062548
# Best possible val right now:2.059097606125096
# Dealer sum:9, Player sum:18
# Accual repeat:1
# Mean value of all repeats:1.529548803062548
# Best possible val right now:2.059097606125096
# Dealer sum:3, Player sum:24
# Accual repeat:2
# Mean value of all repeats:1.529548803062548
# Best possible val right now:2.059097606125096
# Dealer sum:10, Player sum:9
# Accual repeat:0
# Mean value of all repeats:1.5295547272452525
# Best possible val right now:2.059109454490505
# Dealer sum:2, Player sum:14
# Accual repeat:1
# Mean value of all repeats:1.5295547272452525
# Best possible val right now:2.059109454490505
# Dealer sum:8, Player sum:15
# Accual repeat:2
# Mean value of all repeats:1.5295547272452525
# Best possible val right now:2.059109454490505
# Dealer sum:10, Player sum:24
# Accual repeat:3
# Mean value of all repeats:1.5295547272452525
# Best possible val right now:2.059109454490505
# Dealer sum:6, Player sum:20
# Accual repeat:0
# Mean value of all repeats:1.5295732436754688
# Best possible val right now:2.0591464873509375
# Dealer sum:10, Player sum:18
# Accual repeat:0
# Mean value of all repeats:1.5295539829249252
# Best possible val right now:2.0591079658498503
# Dealer sum:3, Player sum:21
# Accual repeat:1
# Mean value of all repeats:1.5295539829249252
# Best possible val right now:2.0591079658498503
# Dealer sum:1, Player sum:21
# Accual repeat:0
# Mean value of all repeats:1.529547314739029
# Best possible val right now:2.059094629478058
# Dealer sum:9, Player sum:17
# Accual repeat:0
# Mean value of all repeats:1.5295280548000403
# Best possible val right now:2.0590561096000806
# Dealer sum:11, Player sum:19
# Accual repeat:1
# Mean value of all repeats:1.5295280548000403
# Best possible val right now:2.0590561096000806
# Dealer sum:7, Player sum:22
# Accual repeat:2
# Mean value of all repeats:1.5295280548000403
# Best possible val right now:2.0590561096000806
# Dealer sum:3, Player sum:7
# Accual repeat:0
# Mean value of all repeats:1.5295339788710225
# Best possible val right now:2.059067957742045
# Dealer sum:5, Player sum:11
# Accual repeat:1
# Mean value of all repeats:1.5295339788710225
# Best possible val right now:2.059067957742045
# Dealer sum:6, Player sum:18
# Accual repeat:2
# Mean value of all repeats:1.5295339788710225
# Best possible val right now:2.059067957742045
# Dealer sum:11, Player sum:22
# Accual repeat:3
# Mean value of all repeats:1.5295339788710225
# Best possible val right now:2.059067957742045
# Dealer sum:4, Player sum:13
# Accual repeat:0
# Mean value of all repeats:1.5295524943967362
# Best possible val right now:2.0591049887934725
# Dealer sum:10, Player sum:15
# Accual repeat:1
# Mean value of all repeats:1.5295524943967362
# Best possible val right now:2.0591049887934725
# Dealer sum:8, Player sum:25
# Accual repeat:2
# Mean value of all repeats:1.5295524943967362
# Best possible val right now:2.0591049887934725
# Dealer sum:8, Player sum:17
# Accual repeat:0
# Mean value of all repeats:1.5295584180108035
# Best possible val right now:2.059116836021607
# Dealer sum:9, Player sum:23
# Accual repeat:1
# Mean value of all repeats:1.5295584180108035
# Best possible val right now:2.059116836021607
# Dealer sum:1, Player sum:11
# Accual repeat:0
# Mean value of all repeats:1.5295517501888694
# Best possible val right now:2.0591035003777387
# Dealer sum:5, Player sum:17
# Accual repeat:1
# Mean value of all repeats:1.5295517501888694
# Best possible val right now:2.0591035003777387
# Dealer sum:10, Player sum:23
# Accual repeat:2
# Mean value of all repeats:1.5295517501888694
# Best possible val right now:2.0591035003777387
# Dealer sum:10, Player sum:10
# Accual repeat:0
# Mean value of all repeats:1.5295576736631369
# Best possible val right now:2.0591153473262738
# Dealer sum:6, Player sum:20
# Accual repeat:1
# Mean value of all repeats:1.5295576736631369
# Best possible val right now:2.0591153473262738
# Dealer sum:2, Player sum:9
# Accual repeat:0
# Mean value of all repeats:1.5295510060184836
# Best possible val right now:2.059102012036967
# Dealer sum:10, Player sum:17
# Accual repeat:1
# Mean value of all repeats:1.5295510060184836
# Best possible val right now:2.059102012036967
# Dealer sum:6, Player sum:27
# Accual repeat:2
# Mean value of all repeats:1.5295510060184836
# Best possible val right now:2.059102012036967
# Dealer sum:9, Player sum:5
# Accual repeat:0
# Mean value of all repeats:1.5295569293529583
# Best possible val right now:2.0591138587059166
# Dealer sum:10, Player sum:9
# Accual repeat:1
# Mean value of all repeats:1.5295569293529583
# Best possible val right now:2.0591138587059166
# Dealer sum:2, Player sum:16
# Accual repeat:2
# Mean value of all repeats:1.5295569293529583
# Best possible val right now:2.0591138587059166
# Dealer sum:11, Player sum:25
# Accual repeat:3
# Mean value of all repeats:1.5295569293529583
# Best possible val right now:2.0591138587059166
# Dealer sum:10, Player sum:11
# Accual repeat:0
# Mean value of all repeats:1.529575443190975
# Best possible val right now:2.05915088638195
# Dealer sum:4, Player sum:16
# Accual repeat:1
# Mean value of all repeats:1.529575443190975
# Best possible val right now:2.05915088638195
# Dealer sum:3, Player sum:23
# Accual repeat:2
# Mean value of all repeats:1.529575443190975
# Best possible val right now:2.05915088638195
# Dealer sum:5, Player sum:12
# Accual repeat:0
# Mean value of all repeats:1.5295813660686182
# Best possible val right now:2.0591627321372363
# Dealer sum:11, Player sum:21
# Accual repeat:1
# Mean value of all repeats:1.5295813660686182
# Best possible val right now:2.0591627321372363
# Dealer sum:1, Player sum:21
# Accual repeat:0
# Mean value of all repeats:1.5295746984614609
# Best possible val right now:2.0591493969229218
# Dealer sum:10, Player sum:19
# Accual repeat:0
# Mean value of all repeats:1.5295554408450527
# Best possible val right now:2.0591108816901054
# Dealer sum:6, Player sum:25
# Accual repeat:1
# Mean value of all repeats:1.5295554408450527
# Best possible val right now:2.0591108816901054
# Dealer sum:10, Player sum:13
# Accual repeat:0
# Mean value of all repeats:1.5295487737321851
# Best possible val right now:2.0590975474643702
# Dealer sum:10, Player sum:23
# Accual repeat:1
# Mean value of all repeats:1.5295487737321851
# Best possible val right now:2.0590975474643702
# Dealer sum:8, Player sum:12
# Accual repeat:0
# Mean value of all repeats:1.5295421067871935
# Best possible val right now:2.059084213574387
# Dealer sum:3, Player sum:14
# Accual repeat:1
# Mean value of all repeats:1.5295421067871935
# Best possible val right now:2.059084213574387
# Dealer sum:7, Player sum:24
# Accual repeat:2
# Mean value of all repeats:1.5295421067871935
# Best possible val right now:2.059084213574387
# Dealer sum:11, Player sum:5
# Accual repeat:0
# Mean value of all repeats:1.529548029711696
# Best possible val right now:2.059096059423392
# Dealer sum:10, Player sum:10
# Accual repeat:1
# Mean value of all repeats:1.529548029711696
# Best possible val right now:2.059096059423392
# Dealer sum:10, Player sum:21
# Accual repeat:2
# Mean value of all repeats:1.529548029711696
# Best possible val right now:2.059096059423392
# Dealer sum:10, Player sum:15
# Accual repeat:0
# Mean value of all repeats:1.5295539524870643
# Best possible val right now:2.0591079049741285
# Dealer sum:7, Player sum:16
# Accual repeat:1
# Mean value of all repeats:1.5295539524870643
# Best possible val right now:2.0591079049741285
# Dealer sum:3, Player sum:21
# Accual repeat:2
# Mean value of all repeats:1.5295539524870643
# Best possible val right now:2.0591079049741285
# Dealer sum:11, Player sum:5
# Accual repeat:0
# Mean value of all repeats:1.5295598751133044
# Best possible val right now:2.0591197502266088
# Dealer sum:6, Player sum:9
# Accual repeat:1
# Mean value of all repeats:1.5295598751133044
# Best possible val right now:2.0591197502266088
# Dealer sum:8, Player sum:17
# Accual repeat:2
# Mean value of all repeats:1.5295598751133044
# Best possible val right now:2.0591197502266088
# Dealer sum:10, Player sum:26
# Accual repeat:3
# Mean value of all repeats:1.5295598751133044
# Best possible val right now:2.0591197502266088
# Dealer sum:1, Player sum:7
# Accual repeat:0
# Mean value of all repeats:1.5295783868165624
# Best possible val right now:2.059156773633125
# Dealer sum:9, Player sum:12
# Accual repeat:1
# Mean value of all repeats:1.5295783868165624
# Best possible val right now:2.059156773633125
# Dealer sum:10, Player sum:23
# Accual repeat:2
# Mean value of all repeats:1.5295783868165624
# Best possible val right now:2.059156773633125
# Dealer sum:10, Player sum:10
# Accual repeat:0
# Mean value of all repeats:1.5295843089860766
# Best possible val right now:2.059168617972153
# Dealer sum:3, Player sum:17
# Accual repeat:1
# Mean value of all repeats:1.5295843089860766
# Best possible val right now:2.059168617972153
# Dealer sum:6, Player sum:27
# Accual repeat:2
# Mean value of all repeats:1.5295843089860766
# Best possible val right now:2.059168617972153
# Dealer sum:7, Player sum:14
# Accual repeat:0
# Mean value of all repeats:1.5295902310064833
# Best possible val right now:2.0591804620129666
# Dealer sum:10, Player sum:25
# Accual repeat:1
# Mean value of all repeats:1.5295902310064833
# Best possible val right now:2.0591804620129666
# Dealer sum:8, Player sum:9
# Accual repeat:0
# Mean value of all repeats:1.529583564127096
# Best possible val right now:2.059167128254192
# Dealer sum:5, Player sum:20
# Accual repeat:1
# Mean value of all repeats:1.529583564127096
# Best possible val right now:2.059167128254192
# Dealer sum:8, Player sum:5
# Accual repeat:0
# Mean value of all repeats:1.529576897415562
# Best possible val right now:2.059153794831124
# Dealer sum:6, Player sum:15
# Accual repeat:1
# Mean value of all repeats:1.529576897415562
# Best possible val right now:2.059153794831124
# Dealer sum:1, Player sum:22
# Accual repeat:2
# Mean value of all repeats:1.529576897415562
# Best possible val right now:2.059153794831124
# Dealer sum:2, Player sum:11
# Accual repeat:0
# Mean value of all repeats:1.529582819305622
# Best possible val right now:2.059165638611244
# Dealer sum:10, Player sum:16
# Accual repeat:1
# Mean value of all repeats:1.529582819305622
# Best possible val right now:2.059165638611244
# Dealer sum:1, Player sum:20
# Accual repeat:2
# Mean value of all repeats:1.529582819305622
# Best possible val right now:2.059165638611244
# Dealer sum:10, Player sum:30
# Accual repeat:3
# Mean value of all repeats:1.529582819305622
# Best possible val right now:2.059165638611244
# Dealer sum:9, Player sum:7
# Accual repeat:0
# Mean value of all repeats:1.5296013293218695
# Best possible val right now:2.059202658643739
# Dealer sum:10, Player sum:8
# Accual repeat:1
# Mean value of all repeats:1.5296013293218695
# Best possible val right now:2.059202658643739
# Dealer sum:3, Player sum:10
# Accual repeat:2
# Mean value of all repeats:1.5296013293218695
# Best possible val right now:2.059202658643739
# Dealer sum:10, Player sum:20
# Accual repeat:3
# Mean value of all repeats:1.5296013293218695
# Best possible val right now:2.059202658643739
# Dealer sum:3, Player sum:31
# Accual repeat:4
# Mean value of all repeats:1.5296013293218695
# Best possible val right now:2.059202658643739
# Dealer sum:4, Player sum:19
# Accual repeat:0
# Mean value of all repeats:1.5296324269889225
# Best possible val right now:2.059264853977845
# Dealer sum:8, Player sum:29
# Accual repeat:1
# Mean value of all repeats:1.5296324269889225
# Best possible val right now:2.059264853977845
# Dealer sum:6, Player sum:15
# Accual repeat:0
# Mean value of all repeats:1.529625759997986
# Best possible val right now:2.059251519995972
# Dealer sum:8, Player sum:25
# Accual repeat:1
# Mean value of all repeats:1.529625759997986
# Best possible val right now:2.059251519995972
# Dealer sum:3, Player sum:15
# Accual repeat:0
# Mean value of all repeats:1.529619093174895
# Best possible val right now:2.05923818634979
# Dealer sum:10, Player sum:24
# Accual repeat:1
# Mean value of all repeats:1.529619093174895
# Best possible val right now:2.05923818634979
# Dealer sum:8, Player sum:8
# Accual repeat:0
# Mean value of all repeats:1.529612426519643
# Best possible val right now:2.059224853039286
# Dealer sum:1, Player sum:15
# Accual repeat:1
# Mean value of all repeats:1.529612426519643
# Best possible val right now:2.059224853039286
# Dealer sum:5, Player sum:26
# Accual repeat:2
# Mean value of all repeats:1.529612426519643
# Best possible val right now:2.059224853039286
# Dealer sum:9, Player sum:11
# Accual repeat:0
# Mean value of all repeats:1.529618347515231
# Best possible val right now:2.059236695030462
# Dealer sum:8, Player sum:18
# Accual repeat:1
# Mean value of all repeats:1.529618347515231
# Best possible val right now:2.059236695030462
# Dealer sum:1, Player sum:28
# Accual repeat:2
# Mean value of all repeats:1.529618347515231
# Best possible val right now:2.059236695030462
# Dealer sum:1, Player sum:21
# Accual repeat:0
# Mean value of all repeats:1.5296242683617598
# Best possible val right now:2.0592485367235196
# Dealer sum:10, Player sum:10
# Accual repeat:0
# Mean value of all repeats:1.5296050147269844
# Best possible val right now:2.059210029453969
# Dealer sum:8, Player sum:20
# Accual repeat:1
# Mean value of all repeats:1.5296050147269844
# Best possible val right now:2.059210029453969
# Dealer sum:2, Player sum:27
# Accual repeat:2
# Mean value of all repeats:1.5296050147269844
# Best possible val right now:2.059210029453969
# Dealer sum:10, Player sum:13
# Accual repeat:0
# Mean value of all repeats:1.5296109355922816
# Best possible val right now:2.059221871184563
# Dealer sum:7, Player sum:23
# Accual repeat:1
# Mean value of all repeats:1.5296109355922816
# Best possible val right now:2.059221871184563
# Dealer sum:6, Player sum:15
# Accual repeat:0
# Mean value of all repeats:1.5296042694592689
# Best possible val right now:2.0592085389185377
# Dealer sum:7, Player sum:18
# Accual repeat:1
# Mean value of all repeats:1.5296042694592689
# Best possible val right now:2.0592085389185377
# Dealer sum:11, Player sum:23
# Accual repeat:2
# Mean value of all repeats:1.5296042694592689
# Best possible val right now:2.0592085389185377
# Dealer sum:10, Player sum:8
# Accual repeat:0
# Mean value of all repeats:1.5296101901848984
# Best possible val right now:2.059220380369797
# Dealer sum:10, Player sum:10
# Accual repeat:1
# Mean value of all repeats:1.5296101901848984
# Best possible val right now:2.059220380369797
# Dealer sum:1, Player sum:15
# Accual repeat:2
# Mean value of all repeats:1.5296101901848984
# Best possible val right now:2.059220380369797
# Dealer sum:8, Player sum:19
# Accual repeat:3
# Mean value of all repeats:1.5296101901848984
# Best possible val right now:2.059220380369797
# Dealer sum:11, Player sum:26
# Accual repeat:4
# Mean value of all repeats:1.5296101901848984
# Best possible val right now:2.059220380369797
# Dealer sum:1, Player sum:14
# Accual repeat:0
# Mean value of all repeats:1.5296412838263058
# Best possible val right now:2.0592825676526116
# (2.24, 0.9911609354691094)

# %% [markdown]
# PPO:\
# 25K = (2.02, 1.2726350615946427)\
# 200K = (1.98, 0.905317623820502)\

# %% [markdown]
# A2C:\
# 25K = (1.28, 1.3862178760930766)
